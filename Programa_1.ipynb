# %% [markdown]
# <a href="https://colab.research.google.com/github/xsmichel07x/Fundamentos/blob/main/Programa_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 5
X = "Carlos"
variableBooleana = True
print("Hola", x, X, "X", variableBooleana)
# Out:
# Hola 5 Carlos X True

# %%
base = input("Dame la base del triángulo")
altura = input("Dame la altura del triángulo")
area = (int(base) * int(altura)) / 2
print("El área del triángulo es", area)
# Out:
# Dame la base del triángulo10
# Dame la altura del triángulo15
# El área del triángulo es 75.0

# %%
z = 10
a = "hola"
print(z * a)
# Out:
# holaholaholaholaholaholaholaholaholahola

# %%
numero1 = 20
numero2 = 40
if numero1 > numero2:
    print("El número", numero1, "es mayor que", numero2)
else:
    print("El número", numero2, "es mayor que", numero1)
# Out:
# El número 40 es mayor que 20

# %%
numero1 = 70
numero2 = 70
if numero1 > numero2:
    print("El número", numero1, "es mayor que", numero2)
elif numero1 == numero2:
    print("Los números son iguales")
else:
    print("El número", numero2, "es mayor que", numero1)
# Out:
# Los números son iguales

# %%
10 > 5
# Out:
# True

# %%
5 > 10
# Out:
# False

# %%
10 > 5 and 5 < 10
# Out:
# True

# %%
10 > 5 and 5 > 10
# Out:
# False

# %%
10 > 5 or 5 > 10
# Out:
# True

# %%
edad = int(input("Dame tu edad "))
if edad <= 10:
    print("Eres un niño")
elif edad <= 18:
    print("Eres un adolescente")
elif edad <= 30:
    print("Eres un adulto joven")
elif edad <= 65:
    print("Eres un adulto")
else: #Para cuando es mayor a 66 años
    print("Eres un adulto mayor")
# Out:
# Dame tu edad 18
# Eres un adolescente

# %%
edad = int(input("Dame tu edad "))
if edad >= 66:
    print("Eres un adulto mayor")
elif edad >= 31 and edad <=65:
    print("Eres un adulto")
elif edad >= 19 and edad <=30:
    print("Eres un adulto joven")
elif edad >= 11 and edad <=18:
    print("Eres un adolescente")
else:
    print("Eres un niño")
# Out:
# Dame tu edad 18
# Eres un adolescente

# %%
#En este caso esta mal implementada la logica pq al ser if´s independientes se van a evaluar cada una de ellas y si ponemos por ejemplo 10 en casi todos los if´s se va a cumplir la condicion y no es lo que queremos
edad = int(input("Dame tu edad "))
if edad <= 10:
    print("Eres un niño")
if edad <= 18:
    print("Eres un adolescente")
if edad <= 30:
    print("Eres un adulto joven")
if edad <= 65:
    print("Eres un adulto")
else: #Para cuando es mayor a 66 años
    print("Eres un adulto mayor")
# Out:
# Dame tu edad 10
# Eres un niño
# Eres un adolescente
# Eres un adulto joven
# Eres un adulto

# %%
tabla = 5
for i in range(1, 11, 2):
    print(tabla, "x", i, "=", tabla * i)
# Out:
# 5 x 1 = 5
# 5 x 3 = 15
# 5 x 5 = 25
# 5 x 7 = 35
# 5 x 9 = 45

# %%
tabla = 10
for i in range(0, 101, 5):
    print(tabla, "x", i, "=", tabla * i)
# Out:
# 10 x 0 = 0
# 10 x 5 = 50
# 10 x 10 = 100
# 10 x 15 = 150
# 10 x 20 = 200
# 10 x 25 = 250
# 10 x 30 = 300
# 10 x 35 = 350
# 10 x 40 = 400
# 10 x 45 = 450
# 10 x 50 = 500
# 10 x 55 = 550
# 10 x 60 = 600
# 10 x 65 = 650
# 10 x 70 = 700
# 10 x 75 = 750
# 10 x 80 = 800
# 10 x 85 = 850
# 10 x 90 = 900
# 10 x 95 = 950
# 10 x 100 = 1000

# %%
numero = 1
while numero <= 5:
  print(numero)
  numero = numero + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
tabla = int(input("Que tabla de multiplicar quieres ver? "))
limiteinicial = int(input("Desde que numero quieres empezar? "))
limitefinal = int(input("Hasta que numero quieres llegar? "))
while limitefinal < limiteinicial:
  print("El limite final no puede ser menor que el inicial")
  limitefinal = int(input("Hasta que numero quieres llegar? "))
incrementos= int(input("De cuanto en cuanto quieres que vaya? "))
 for i in range(limiteinicial, limitefinal + 1, incrementos):
    print(tabla, "x", i, "=", tabla * i)
# Out:
# Que tabla de multiplicar quieres ver? 10
# Desde que numero quieres empezar? 10
# Hasta que numero quieres llegar? 0
# El limite final no puede ser menor que el inicial
# Hasta que numero quieres llegar? 101
# De cuanto en cuanto quieres que vaya? 10
# 10 x 10 = 100
# 10 x 20 = 200
# 10 x 30 = 300
# 10 x 40 = 400
# 10 x 50 = 500
# 10 x 60 = 600
# 10 x 70 = 700
# 10 x 80 = 800
# 10 x 90 = 900
# 10 x 100 = 1000

# %% [markdown]
# # **Tema de listas**

# %%
alumnos = ["Ana", "Luis", "Carlos", "Juan"]
print(alumnos)
print(alumnos[0])
print(alumnos[3])
print(alumnos[5])
# Out:
# ['Ana', 'Luis', 'Carlos', 'Juan']
# Ana
# Juan
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1515/2272696650.py in <cell line: 0>()
#       3 print(alumnos[0])
#       4 print(alumnos[3])
# ----> 5 print(alumnos[5])
#
# IndexError: list index out of range
